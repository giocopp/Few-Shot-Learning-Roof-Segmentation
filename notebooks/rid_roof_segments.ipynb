# %%
# define superstructure segments
label_classes_superstructures_annotation_experiment = ['pvmodule', 'dormer', 'window', 'ladder', 'chimney', 'shadow',
                                                       'tree', 'unknown']

# %%
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# Notebook is running in repo_root/notebooks/
BASE_DIR = Path().resolve()

img_path = BASE_DIR.parent / "data" / "images_roof_centered_geotiff" / "21452.tif"

print("Trying path:", img_path)
print("Exists:", img_path.exists())

img = np.array(Image.open(img_path))
plt.imshow(img)
plt.show()
# Out:
# Trying path: /Users/elena/SynologyDrive/Hertie/semester_3/deep-learning/assignments/tutorial/tutorial-new-tutorial-group-1/data/images_roof_centered_geotiff/21452.tif
# Exists: False
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 14
#      11 print("Trying path:", img_path)
#      12 print("Exists:", img_path.exists())
# ---> 14 img = np.array(Image.open(img_path))
#      15 plt.imshow(img)
#      16 plt.show()
#
# File ~/miniconda3/envs/.venv-dl-ps1/lib/python3.10/site-packages/PIL/Image.py:3513, in open(fp, mode, formats)
#    3511 if is_path(fp):
#    3512     filename = os.fspath(fp)
# -> 3513     fp = builtins.open(filename, "rb")
#    3514     exclusive_fp = True
#    3515 else:
#
# ...

# %%
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

img_path = Path("..") / "data" / "images_roof_centered_geotiff" / "21452.tif"
img = np.array(Image.open(img_path))
plt.imshow(img)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 7
#       4 from PIL import Image
#       6 img_path = Path("..") / "data" / "images_roof_centered_geotiff" / "21452.tif"
# ----> 7 img = np.array(Image.open(img_path))
#       8 plt.imshow(img)
#       9 plt.show()
#
# File ~/miniconda3/envs/.venv-dl-ps1/lib/python3.10/site-packages/PIL/Image.py:3513, in open(fp, mode, formats)
#    3511 if is_path(fp):
#    3512     filename = os.fspath(fp)
# -> 3513     fp = builtins.open(filename, "rb")
#    3514     exclusive_fp = True
#    3515 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/images_roof_centered_geotiff/21452.tif'
